# %%
# %pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in d:\programmes\coding\python\lib\site-packages (0.22.0)
# Requirement already satisfied: scipy>=1.2.1 in d:\programmes\coding\python\lib\site-packages (from mlxtend) (1.9.3)
# Requirement already satisfied: numpy>=1.16.2 in d:\programmes\coding\python\lib\site-packages (from mlxtend) (1.24.2)
# Requirement already satisfied: pandas>=0.24.2 in d:\programmes\coding\python\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in d:\programmes\coding\python\lib\site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in d:\programmes\coding\python\lib\site-packages (from mlxtend) (3.6.2)
# Requirement already satisfied: joblib>=0.13.2 in d:\programmes\coding\python\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: setuptools in d:\programmes\coding\python\lib\site-packages (from mlxtend) (56.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programmes\coding\python\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in d:\programmes\coding\python\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programmes\coding\python\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\programmes\coding\python\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\programmes\coding\python\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\programmes\coding\python\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\programmes\coding\python\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abdellatif-kbr\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\programmes\coding\python\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programmes\coding\python\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in d:\programmes\coding\python\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('Data/data.csv',
                 header=0,
                 encoding='unicode_escape',
                 dtype={'CustomerID': str,
                        'InvoiceID': str},
                 parse_dates=['InvoiceDate'],
                 infer_datetime_format=True)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom

# %% [markdown]
# # Reducing the size of the data set

# %%
sampleData = df.sample(frac=0.3)

sampleData
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540158    581469     21704              BAG 250g SWIRLY MARBLES         1
# 319226    564843     22878        NUMBER TILE COTTAGE GARDEN No         1
# 372177    569234     23080             RED METAL BOX TOP SECRET         1
# 367930    568912     23275     SET OF 3 HANGING OWLS OLLIE BEAK        12
# 215566    555722    85131B  BEADED CRYSTAL HEART GREEN ON STICK         1
# ...          ...       ...                                  ...       ...
# 139094    548289     22917                 HERB MARKER ROSEMARY        12
# 539212    581439     23340         VINTAGE CHRISTMAS CAKE FRILL         1
# 499974    578703     20931               BLUE POT PLANT CANDLE          2
# 424994    573300     22905            CALENDAR IN SEASON DESIGN         2
# 375992    569491     22551             PLASTERS IN TIN SPACEBOY         5
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 540158 2011-12-08 19:28:00       0.85      14606  United Kingdom
# 319226 2011-08-30 14:09:00       2.10      15866  United Kingdom
# 372177 2011-10-02 15:33:00       8.25      17841  United Kingdom
# 367930 2011-09-29 13:45:00       1.25      17528  United Kingdom
# 215566 2011-06-06 16:06:00       0.83        NaN  United Kingdom
# ...                    ...        ...        ...             ...
# 139094 2011-03-30 11:48:00       0.65      13988  United Kingdom
# 539212 2011-12-08 16:30:00       3.29        NaN  United Kingdom
# 499974 2011-11-25 11:02:00       2.95      17385  United Kingdom
# 424994 2011-10-28 16:10:00       2.95      16049  United Kingdom
# 375992 2011-10-04 13:25:00       1.65      14056  United Kingdom
#
# [162573 rows x 8 columns]

# %%
mbAnalysis = sampleData[['CustomerID', 'InvoiceDate', 'Description']]
mbAnalysis.head()
# Out:
#        CustomerID         InvoiceDate                          Description
# 540158      14606 2011-12-08 19:28:00              BAG 250g SWIRLY MARBLES
# 319226      15866 2011-08-30 14:09:00        NUMBER TILE COTTAGE GARDEN No
# 372177      17841 2011-10-02 15:33:00             RED METAL BOX TOP SECRET
# 367930      17528 2011-09-29 13:45:00     SET OF 3 HANGING OWLS OLLIE BEAK
# 215566        NaN 2011-06-06 16:06:00  BEADED CRYSTAL HEART GREEN ON STICK

# %%
mbAnalysis['single_transaction'] = df['CustomerID'].astype(
    str) + '_' + df['InvoiceDate'].astype(str).str.split(" ").str[0]

mbAnalysis.head()
# Out:
# C:\Users\ABDELL~1\AppData\Local\Temp/ipykernel_3424/2271649286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mbAnalysis['single_transaction'] = df['CustomerID'].astype(
#        CustomerID         InvoiceDate                          Description  \
# 540158      14606 2011-12-08 19:28:00              BAG 250g SWIRLY MARBLES
# 319226      15866 2011-08-30 14:09:00        NUMBER TILE COTTAGE GARDEN No
# 372177      17841 2011-10-02 15:33:00             RED METAL BOX TOP SECRET
# 367930      17528 2011-09-29 13:45:00     SET OF 3 HANGING OWLS OLLIE BEAK
# 215566        NaN 2011-06-06 16:06:00  BEADED CRYSTAL HEART GREEN ON STICK
#
#        single_transaction
# 540158   14606_2011-12-08
# 319226   15866_2011-08-30
# 372177   17841_2011-10-02
# 367930   17528_2011-09-29
# 215566     nan_2011-06-06

# %%
df2 = pd.crosstab(mbAnalysis['single_transaction'],
                  mbAnalysis['Description'])
df2.head()
# Out:
# Description          4 PURPLE FLOCK DINNER CANDLES  \
# single_transaction
# 12346_2011-01-18                                 0
# 12347_2010-12-07                                 0
# 12347_2011-01-26                                 0
# 12347_2011-04-07                                 0
# 12347_2011-06-09                                 0
#
# Description          50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# single_transaction
# 12346_2011-01-18                                 0                   0
# 12347_2010-12-07                                 0                   0
# 12347_2011-01-26                                 0                   0
# 12347_2011-04-07                                 0                   0
# 12347_2011-06-09                                 0                   0
#
# Description          I LOVE LONDON MINI BACKPACK  \
# single_transaction
# 12346_2011-01-18                               0
# 12347_2010-12-07                               0
# 12347_2011-01-26                               0
# 12347_2011-04-07                               0
# 12347_2011-06-09                               0
#
# Description          I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# single_transaction
# 12346_2011-01-18                               0                         0
# 12347_2010-12-07                               0                         0
# 12347_2011-01-26                               0                         0
# 12347_2011-04-07                               0                         0
# 12347_2011-06-09                               0                         0
#
# Description          OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# single_transaction
# 12346_2011-01-18                              0                         0
# 12347_2010-12-07                              0                         0
# 12347_2011-01-26                              0                         0
# 12347_2011-04-07                              0                         0
# 12347_2011-06-09                              0                         0
#
# Description          SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# single_transaction
# 12346_2011-01-18                                   0                        0
# 12347_2010-12-07                                   0                        0
# 12347_2011-01-26                                   0                        0
# 12347_2011-04-07                                   0                        0
# 12347_2011-06-09                                   0                        0
#
# Description         ...  water damaged  website fixed  wet damaged  \
# single_transaction  ...
# 12346_2011-01-18    ...              0              0            0
# 12347_2010-12-07    ...              0              0            0
# 12347_2011-01-26    ...              0              0            0
# 12347_2011-04-07    ...              0              0            0
# 12347_2011-06-09    ...              0              0            0
#
# Description         wet pallet  wet rusty  wet/rusty  wet?  wrong barcode  \
# single_transaction
# 12346_2011-01-18             0          0          0     0              0
# 12347_2010-12-07             0          0          0     0              0
# 12347_2011-01-26             0          0          0     0              0
# 12347_2011-04-07             0          0          0     0              0
# 12347_2011-06-09             0          0          0     0              0
#
# Description         wrong barcode (22467)  wrongly marked 23343
# single_transaction
# 12346_2011-01-18                        0                     0
# 12347_2010-12-07                        0                     0
# 12347_2011-01-26                        0                     0
# 12347_2011-04-07                        0                     0
# 12347_2011-06-09                        0                     0
#
# [5 rows x 3840 columns]

# %%
def encode(item_freq):
    res = 0
    if item_freq > 0:
        res = 1
    return res


basket_input = df2.applymap(encode)

# %%
sample_train =  basket_input.sample(frac=0.35,random_state=42)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

frequent_itemsets = apriori(sample_train,
                            min_support=0.005,
                            use_colnames=True)

rules = association_rules(frequent_itemsets, metric="lift")

rules
# Out:
# d:\Programmes\Coding\Python\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                            antecedents                         consequents  \
# 0            (JUMBO BAG RED RETROSPOT)                    (DOTCOM POSTAGE)
# 1                     (DOTCOM POSTAGE)           (JUMBO BAG RED RETROSPOT)
# 2   (ROSES REGENCY TEACUP AND SAUCER )   (GREEN REGENCY TEACUP AND SAUCER)
# 3    (GREEN REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER )
# 4            (JUMBO BAG RED RETROSPOT)           (JUMBO BAG PINK POLKADOT)
# 5            (JUMBO BAG PINK POLKADOT)           (JUMBO BAG RED RETROSPOT)
# 6            (JUMBO BAG RED RETROSPOT)            (JUMBO STORAGE BAG SUKI)
# 7             (JUMBO STORAGE BAG SUKI)           (JUMBO BAG RED RETROSPOT)
# 8            (LUNCH BAG RED RETROSPOT)           (JUMBO BAG RED RETROSPOT)
# 9            (JUMBO BAG RED RETROSPOT)           (LUNCH BAG RED RETROSPOT)
# 10           (JUMBO BAG RED RETROSPOT)   (PACK OF 72 RETROSPOT CAKE CASES)
# 11   (PACK OF 72 RETROSPOT CAKE CASES)           (JUMBO BAG RED RETROSPOT)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.040924            0.009509  0.005094    0.124481  13.090545
# 1             0.009509            0.040924  0.005094    0.535714  13.090545
# 2             0.021056            0.019528  0.006283    0.298387  15.280014
# 3             0.019528            0.021056  0.006283    0.321739  15.280014
# 4             0.040924            0.024283  0.007132    0.174274   7.176914
# 5             0.024283            0.040924  0.007132    0.293706   7.176914
# 6             0.040924            0.022584  0.006113    0.149378   6.614170
# 7             0.022584            0.040924  0.006113    0.270677   6.614170
# 8             0.028188            0.040924  0.005434    0.192771   4.710493
# 9             0.040924            0.028188  0.005434    0.132780   4.710493
# 10            0.040924            0.022924  0.005094    0.124481   5.430152
# 11            0.022924            0.040924  0.005094    0.222222   5.430152
#
#     leverage  conviction  zhangs_metric
# 0   0.004705    1.131319       0.963019
# 1   0.004705    2.065703       0.932476
# 2   0.005872    1.397454       0.954656
# 3   0.005872    1.443315       0.953168
# 4   0.006138    1.181648       0.897389
# 5   0.006138    1.357900       0.882084
# 6   0.005189    1.149059       0.885028
# 7   0.005189    1.315022       0.868422
# 8   0.004280    1.188109       0.810556
# 9   0.004280    1.120606       0.821319
# 10  0.004156    1.115997       0.850655
# 11  0.004156    1.233098       0.834984

# %%
rules.sort_values(["support", "confidence","lift"],axis = 0, ascending = False).head(8)
# Out:
#                           antecedents                         consequents  \
# 5           (JUMBO BAG PINK POLKADOT)           (JUMBO BAG RED RETROSPOT)
# 4           (JUMBO BAG RED RETROSPOT)           (JUMBO BAG PINK POLKADOT)
# 3   (GREEN REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER )
# 2  (ROSES REGENCY TEACUP AND SAUCER )   (GREEN REGENCY TEACUP AND SAUCER)
# 7            (JUMBO STORAGE BAG SUKI)           (JUMBO BAG RED RETROSPOT)
# 6           (JUMBO BAG RED RETROSPOT)            (JUMBO STORAGE BAG SUKI)
# 8           (LUNCH BAG RED RETROSPOT)           (JUMBO BAG RED RETROSPOT)
# 9           (JUMBO BAG RED RETROSPOT)           (LUNCH BAG RED RETROSPOT)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 5            0.024283            0.040924  0.007132    0.293706   7.176914
# 4            0.040924            0.024283  0.007132    0.174274   7.176914
# 3            0.019528            0.021056  0.006283    0.321739  15.280014
# 2            0.021056            0.019528  0.006283    0.298387  15.280014
# 7            0.022584            0.040924  0.006113    0.270677   6.614170
# 6            0.040924            0.022584  0.006113    0.149378   6.614170
# 8            0.028188            0.040924  0.005434    0.192771   4.710493
# 9            0.040924            0.028188  0.005434    0.132780   4.710493
#
#    leverage  conviction  zhangs_metric
# 5  0.006138    1.357900       0.882084
# 4  0.006138    1.181648       0.897389
# 3  0.005872    1.443315       0.953168
# 2  0.005872    1.397454       0.954656
# 7  0.005189    1.315022       0.868422
# 6  0.005189    1.149059       0.885028
# 8  0.004280    1.188109       0.810556
# 9  0.004280    1.120606       0.821319
