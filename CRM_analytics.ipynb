# %%
# %pip install mlxtend
# Out:
# ...
#   Using cached mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
# ...
#   Using cached scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\ABDELL~1\AppData\Local\Temp/ipykernel_18140/4080736814.py in <module>
# ----> 1 import pandas as pd
#
# D:\Programmes\Anaconda3\lib\site-packages\pandas\__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat import (
#      23     np_version_under1p18 as _np_version_under1p18,
#      24     is_numpy_dev as _is_numpy_dev,
#
# D:\Programmes\Anaconda3\lib\site-packages\pandas\compat\__init__.py in <module>
#      13
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_array_datetime64_compat,
#
# D:\Programmes\Anaconda3\lib\site-packages\pandas\compat\numpy\__init__.py in <module>
#       5 import numpy as np
#       6
# ----> 7 from pandas.util.version import Version
#       8
#       9 # numpy versioning
#
# ...

# %%
df = pd.read_csv('Data/input/data.csv',
                 header=0,
                 encoding='unicode_escape',
                 dtype={'CustomerID': str,
                        'InvoiceID': str},
                 parse_dates=['InvoiceDate'],
                 infer_datetime_format=True)
df.head()

# %% [markdown]
# # Reducing the size of the data set

# %%
sampleData = df.sample(frac=0.3)

sampleData[sampleData["CustomerID"] != 'NaN']

# %%
mbAnalysis = sampleData[['CustomerID', 'InvoiceDate', 'Description']]
mbAnalysis.head()

# %%
mbAnalysis['single_transaction'] = df['CustomerID'].astype(
    str) + '_' + df['InvoiceDate'].astype(str).str.split(" ").str[0]

mbAnalysis.head()

# %%
df2 = pd.crosstab(mbAnalysis['single_transaction'],
                  mbAnalysis['Description'])
df2.head()

# %%
def encode(item_freq):
    res = 0
    if item_freq > 0:
        res = 1
    return res


basket_input = df2.applymap(encode)

# %%
sample_train =  basket_input.sample(frac=0.35,random_state=42)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

frequent_itemsets = apriori(sample_train,
                            min_support=0.005,
                            use_colnames=True)

rules = association_rules(frequent_itemsets, metric="lift")

rules

# %%
rules.sort_values(["support", "confidence","lift"],axis = 0, ascending = False).head(8)
